# %% [markdown]
# # Analysis of early 2020 Democratic campaign co-donors
#
# This notebook analyzes contribution data from Democratic presidential campaigns' FEC filings for the first quarter of 2019.

# %% [markdown]
# *Added by Steve*
#
# See article [BuzzFeed News article examining donors](https://www.buzzfeednews.com/article/tariniparti/democratic-donors-2020-candidates).
#
# This article analyzed how a money is distributed

# %% [markdown]
# ## Load candidate, committee, and filing data

# %%
import pandas as pd
import fecfile

# %% [markdown]
# *Added by Steve*
#
# See more about `fecfile` at https://esonderegger.github.io/fecfile/

# %% [markdown]
# ### Candidates

# %%
candidates = pd.read_csv("../inputs/candidates.csv")

candidates
# Out:
#         Candidate Name Candidate Sex                Committee Name  \
# 0        Amy Klobuchar             F               Amy for America
# 1          Andrew Yang             M        Friends of Andrew Yang
# 2       Bernie Sanders             M                   Bernie 2020
# 3        Beto O'Rourke             M              Beto for America
# 4          Cory Booker             M                     Cory 2020
# 5     Elizabeth Warren             F          Warren for President
# 6           Jay Inslee             M            Inslee for America
# 7         John Delaney             M       Friends of John Delaney
# 8    John Hickenlooper             M             Hickenlooper 2020
# 9        Julián Castro             M         Julián for the Future
# 10       Kamala Harris             F  Kamala Harris for the People
# 11  Kirsten Gillibrand             F               Gillibrand 2020
# 12      Pete Buttigieg             M              Pete for America
# 13       Tulsi Gabbard             F                     Tulsi Now
# 14        Wayne Messam             M      Wayne Messam for America
#
#    committee_id
# 0     C00696419
# 1     C00659938
# 2     C00696948
# 3     C00699090
# 4     C00695510
# 5     C00693234
# 6     C00698050
# 7     C00508416
# 8     C00698258
# 9     C00693044
# 10    C00694455
# 11    C00694018
# 12    C00697441
# 13    C00693713
# 14    C00699280

# %% [markdown]
# ### Filing metadata
#
# Here, we load basic metadata about each filing, and also calculate what proportion of money raised from individual contributions has been itemized in each candidate/committee's filings:

# %%
filings = pd.read_csv(
    "../inputs/filings.csv",
    low_memory = False
)

filings
# Out:
#         Candidate Name committee_id  filing_id   report_title  \
# 0        Amy Klobuchar    C00696419    1326529  APR QUARTERLY
# 1          Andrew Yang    C00659938    1326379  APR QUARTERLY
# 2       Bernie Sanders    C00696948    1326070  APR QUARTERLY
# 3        Beto O'Rourke    C00699090    1326481  APR QUARTERLY
# 4          Cory Booker    C00695510    1326465  APR QUARTERLY
# 5     Elizabeth Warren    C00693234    1326299  APR QUARTERLY
# 6           Jay Inslee    C00698050    1326136  APR QUARTERLY
# 7         John Delaney    C00508416    1324749  APR QUARTERLY
# 8    John Hickenlooper    C00698258    1326014  APR QUARTERLY
# 9        Julián Castro    C00693044    1326324  APR QUARTERLY
# 10       Kamala Harris    C00694455    1326016  APR QUARTERLY
# 11  Kirsten Gillibrand    C00694018    1326061  APR QUARTERLY
# 12      Pete Buttigieg    C00697441    1324922  APR QUARTERLY
# 13       Tulsi Gabbard    C00693713    1326558  APR QUARTERLY
# 14        Wayne Messam    C00699280    1326345  APR QUARTERLY
#
#    date_coverage_from date_coverage_to  amended
# 0          2019-02-07       2019-03-31    False
# 1          2019-01-01       2019-03-31    False
# 2          2019-01-01       2019-03-31    False
# 3          2019-03-14       2019-03-31    False
# 4          2019-01-01       2019-03-31    False
# 5          2019-01-01       2019-03-31    False
# 6          2019-02-14       2019-03-31    False
# 7          2019-01-01       2019-03-31    False
# 8          2019-01-01       2019-03-31    False
# 9          2019-01-01       2019-03-31    False
# 10         2019-01-21       2019-03-31    False
# 11         2019-01-01       2019-03-31    False
# 12         2019-01-01       2019-03-31    False
# 13         2019-01-11       2019-03-31    False
# 14         2019-01-01       2019-03-31    False

# %%
def get_additional_metadata(filing_id):
    filing = fecfile.from_file(f"../inputs/filings/{int(filing_id)}.fec")
    data = dict((c, filing["filing"][c]) for c in [
        "col_a_individuals_itemized",
        "col_a_individuals_unitemized",
        "col_a_individual_contribution_total",
    ])
    data["filing_id"] = int(filing_id)
    return data

# %%
additional_filing_metadata = pd.DataFrame([
    get_additional_metadata(filing_id)
    for filing_id in filings["filing_id"]
])

additional_filing_metadata.head()
# Out:
#    col_a_individual_contribution_total  col_a_individuals_itemized  \
# 0                           5232375.87                  3421762.07
# 1                           1776875.12                   342170.20
# 2                          18186300.21                  2904271.23
# 3                           9369861.40                  3827220.52
# 4                           5044390.15                  4238894.87
#
#    col_a_individuals_unitemized  filing_id
# 0                    1810613.80    1326529
# 1                    1434704.92    1326379
# 2                   15282028.98    1326070
# 3                    5542640.88    1326481
# 4                     805495.28    1326465

# %%
# Added by Steve

additional_filing_metadata['is_equal'] = (additional_filing_metadata.col_a_individuals_itemized + \
    additional_filing_metadata.col_a_individuals_unitemized) \
    == additional_filing_metadata.col_a_individual_contribution_total

additional_filing_metadata
# Out:
#     col_a_individual_contribution_total  col_a_individuals_itemized  \
# 0                            5232375.87                  3421762.07
# 1                            1776875.12                   342170.20
# 2                           18186300.21                  2904271.23
# 3                            9369861.40                  3827220.52
# 4                            5044390.15                  4238894.87
# 5                            6016435.38                  1786711.53
# 6                            2255455.41                  1488634.36
# 7                             404301.17                   331244.84
# 8                            2014099.37                  1813358.33
# 9                            1092941.02                   719775.12
# 10                          12024121.55                  7603293.36
# 11                           2997884.10                  2497960.90
# 12                           7086154.62                  2549602.40
# 13                           1949074.92                   881878.80
# 14                             43531.62                    31960.00
#
#     col_a_individuals_unitemized  filing_id  is_equal
# 0                     1810613.80    1326529      True
# 1                     1434704.92    1326379     False
# 2                    15282028.98    1326070      True
# 3                     5542640.88    1326481      True
# 4                      805495.28    1326465      True
# 5                     4229723.85    1326299      True
# 6                      766821.05    1326136      True
# 7                       73056.33    1324749     False
# 8                      200741.04    1326014      True
# 9                      373165.90    1326324      True
# 10                    4420828.19    1326016      True
# 11                     499923.20    1326061      True
# 12                    4536552.22    1324922     False
# 13                    1067196.12    1326558     False
# 14                      11571.62    1326345      True

# %%
(
    filings
    [[
        "filing_id",
        "Candidate Name",
    ]]
    .merge(
        additional_filing_metadata
        [[
            "filing_id",
            "col_a_individuals_itemized",
            "col_a_individuals_unitemized",
            "col_a_individual_contribution_total",
        ]]
        .assign(
            prop_itemized = lambda df: (
                df["col_a_individuals_itemized"] / 
                df["col_a_individual_contribution_total"]
            ).round(3)
        ),
        how = "right",
        on = "filing_id"
    )
    .sort_values("col_a_individuals_itemized", ascending = False)
)
# Out:
#     filing_id      Candidate Name  col_a_individuals_itemized  \
# 10    1326016       Kamala Harris                  7603293.36
# 4     1326465         Cory Booker                  4238894.87
# 3     1326481       Beto O'Rourke                  3827220.52
# 0     1326529       Amy Klobuchar                  3421762.07
# 2     1326070      Bernie Sanders                  2904271.23
# 12    1324922      Pete Buttigieg                  2549602.40
# 11    1326061  Kirsten Gillibrand                  2497960.90
# 8     1326014   John Hickenlooper                  1813358.33
# 5     1326299    Elizabeth Warren                  1786711.53
# 6     1326136          Jay Inslee                  1488634.36
# 13    1326558       Tulsi Gabbard                   881878.80
# 9     1326324       Julián Castro                   719775.12
# 1     1326379         Andrew Yang                   342170.20
# 7     1324749        John Delaney                   331244.84
# 14    1326345        Wayne Messam                    31960.00
#
#     col_a_individuals_unitemized  col_a_individual_contribution_total  \
# 10                    4420828.19                          12024121.55
# 4                      805495.28                           5044390.15
# 3                     5542640.88                           9369861.40
# 0                     1810613.80                           5232375.87
# 2                    15282028.98                          18186300.21
# 12                    4536552.22                           7086154.62
# 11                     499923.20                           2997884.10
# 8                      200741.04                           2014099.37
# 5                     4229723.85                           6016435.38
# 6                      766821.05                           2255455.41
# 13                    1067196.12                           1949074.92
# 9                      373165.90                           1092941.02
# 1                     1434704.92                           1776875.12
# 7                       73056.33                            404301.17
# 14                      11571.62                             43531.62
#
#     prop_itemized
# 10          0.632
# 4           0.840
# 3           0.408
# 0           0.654
# 2           0.160
# 12          0.360
# 11          0.833
# 8           0.900
# 5           0.297
# 6           0.660
# 13          0.452
# 9           0.659
# 1           0.193
# 7           0.819
# 14          0.734

# %% [markdown]
# ### Contributors
#
# Here, we extract contributions to the committees from individuals, and assign `donor_id`s: a combination of the contributor's listed first name, last name, and five-digit ZIP code.

# %%
def make_donor_ids(df):
    return (
        df
        .assign(
            donor_id = lambda df: (
                df
                .assign(
                    zip5 = lambda df: (
                        df["contributor_zip_code"]
                        .fillna("-----")
                        .str.slice(0, 5)
                    )
                )
                [[
                    "contributor_first_name",
                    "contributor_last_name",
                    "zip5",
                ]]
                .apply(lambda x: (
                    x
                    .fillna("")
                    .astype(str)
                    # Remove periods, commas, extra whitespace
                    .str.replace(r"[\.,\s]+", " ")
                    .str.strip()
                    # Convert everything to upper-case
                    .str.upper()
                ))
                .apply("|".join, axis = 1)
            )
        )
    )

# %%
def extract_indiv_contributions(filing_id):
    filing = fecfile.from_file(f"../inputs/filings/{int(filing_id)}.fec")
    df = pd.DataFrame(filing["itemizations"]["Schedule A"])
    return (
        df
        # Extract only individual contributions
        .loc[lambda df: df["entity_type"] == "IND"]
        # Remove memo lines
        .loc[lambda df: df["memo_code"] == ""]
        .pipe(make_donor_ids)
        .assign(
            filing_id = int(filing_id)
        )
        [[
            "filer_committee_id_number",
            "filing_id",
            "transaction_id",
            "contribution_date",
            "contribution_amount",
# 67 2019-03-29 00:00:00-04:00              2500.00                 2500.00
#
#                     donor_id contributor_first_name contributor_last_name  \
# 0      JUSTINE|HASELOW|55436                Justine               Haselow
# 1       MARTIN|CARLSON|55401                 Martin               Carlson
# 3         WILLIAM|BELL|90068                William                  Bell
# 5      REBECCA|BEATTIE|80007                Rebecca               Beattie
# 7       CAROLINE|TOWER|94115               Caroline                 Tower
# 9        ROLLYN|STRAND|56225                 Rollyn                Strand
# 11      STEVEN|WAYLAND|60614                 Steven               Wayland
# 13        JAMES|MORRIS|30338                  James                Morris
# 15        WARREN|TRIPP|53711                 Warren                 Tripp
# 17        ALEC|BRINDLE|98199                   Alec               Brindle
# 19    STEPHANIE|MELLIN|94118              Stephanie                Mellin
# 21          DAVID|HILL|06355                  David                  Hill
# 23          AZITA|RAJI|94920                  Azita                  Raji
# 25        GARY|COSTLEY|34145                   Gary               Costley
# 27       JOHN|SCHRAGER|55126                   John              Schrager
# 29         JOEL|OSTROW|60015                   Joel                Ostrow
# 31          MIKE|SEGAL|33160                   Mike                 Segal
# 33       ERIC|BOBINSKY|44017                   Eric              Bobinsky
# 35          SEAN|DAVIS|10036                   Sean                 Davis
# 37         DOUG|ROGAHN|55443                   Doug                Rogahn
# 39          JOE|FOSTER|94114                    Joe                Foster
# 41        HENRY|NEWELL|53711                  Henry                Newell
# 43     PHILLIP|WAKELYN|20815                Phillip               Wakelyn
# 45         CHAD|DAYTON|55102                   Chad                Dayton
# 47          MOLLY|RICE|55424                  Molly                  Rice
# 49     LISA|BAINBRIDGE|37069                   Lisa            Bainbridge
# 50  ROBERT|RUTISHAUSER|78731                 Robert           Rutishauser
# 51        PETER|LENKOV|91302                  Peter                Lenkov
# 53          SCOTT|SIFF|20008                  Scott                  Siff
# 55      MISSY|THOMPSON|55102                  Missy              Thompson
# ..                       ...                    ...                   ...
# 10      MICHAEL|POWELL|85249                Michael                Powell
# 12        JOHN|STCLAIR|33028                   John               Stclair
# 14    MATTHEW|THOMPSON|33027                Matthew              Thompson
# 16          DAVID|VAIL|33029                  David                  Vail
# 18        ZHILONG|YANG|33027                Zhilong                  Yang
# 20    CHARLES|THOMPSON|34987                Charles              Thompson
# 21     JAMES|ALEXANDER|33020                  James             Alexander
# 23     PORTER|ANDERSON|33133                 Porter              Anderson
# 25        RANDY|BARNES|33809                  Randy                Barnes
# 27        MARIDEE|BELL|33019                Maridee                  Bell
# 29    TERRENCE|BOATMAN|32341               Terrence               Boatman
# 31      DWAYNE|BROXTON|77583                 Dwayne               Broxton
# 33     VINCENT|BURNETT|33025                Vincent               Burnett
# 35        LESLIE|CADET|33027                 Leslie                 Cadet
# 37    ZACHARY|CROCKETT|33138                Zachary              Crockett
# 39      LEIROI|DANIELS|77479                 Leiroi               Daniels
# 41       ALBERT|DOTSON|33156                 Albert                Dotson
# 43      JOHN|DUKES III|32605                   John             Dukes III
# 45       BERNICE|DUKES|32601                Bernice                 Dukes
# 47        CECIL|HOWARD|33508                  Cecil                Howard
# 49     YOLANDA|JACKSON|33015                Yolanda               Jackson
# 51     GWENDOLYN|JONAS|33625              Gwendolyn                 Jonas
# 53   CHRISTOPHER|LOMAX|33134            Christopher                 Lomax
# 55       AUBREY|LOWERY|33981                 Aubrey                Lowery
# 57          JOHN|OWENS|33140                   John                 Owens
# 59      MICHAEL|POWELL|85249                Michael                Powell
# 61          LARRY|RUSS|45040                  Larry                  Russ
# 63     DERRICK|SADDLER|34638                Derrick               Saddler
# 65      MATTHEW|WILDER|91403                Matthew                Wilder
# 67  DARRELL D|WILLIAMS|33594             Darrell D.              Williams
#
#    contributor_zip_code
# 0             554361001
# 1             554012159
# 3             900682646
# 5             800076971
# 7             941152418
# 9             562250418
# 11            606141116
# 13            303384548
# 15            537115288
# 17            981993802
# 19            941181849
# 21            063552309
# 23            949202434
# 25            341455859
# 27            551262381
# 29            600155059
# 31            331604916
# 33            440172531
# 35            100362010
# 37            554431750
# 39            941141804
# 41            537113712
# 43            208157114
# 45            551022124
# 47            554241232
# 49            370697253
# 50            787316061
# 51            913021129
# 53            200083116
# 55            551022219
# ..                  ...
# 10            852494576
# 12            330282603
# 14            330272670
# 16            330295861
# 18            330274378
# 20            349872480
# 21            330202313
# 23            331337039
# 25            338092370
# 27            330192403
# 29            323410918
# 31            775834583
# 33            330255671
# 35            330273968
# 37            331382708
# 39            774791667
# 41            331564330
# 43            326053907
# 45            326013212
# 47            335086019
# 49            330156924
# 51            336256620
# 53            331342423
# 55            339811034
# 57            331404344
# 59            852494576
# 61            450408772
# 63            346387994
# 65            914032810
# 67            335944084
#
# [92830 rows x 10 columns]

# %%
all_indiv_contribs = (
    
    # Steve: Union "tables" of individual filings into one master table
    pd.concat([
        extract_indiv_contributions(filing_id)
        for filing_id in filings["filing_id"]
    ])
    
    # Steve: Add filing metadata to individual records
    .merge(
        (
            filings
            [[
                "filing_id",
                "committee_id",
            ]]
        ),
        how = "left",
        on = "filing_id",
    )
    
    # Steve: An more semantic metadata to individual records
    .merge(
        (
            candidates
            [[
                "committee_id",
                "Candidate Name",
            ]]
        ),
        how = "left",
        on = "committee_id",
    )
)

len(all_indiv_contribs)
# Out:
# 92830

# %%
all_indiv_contribs.head()
# Out:
#   filer_committee_id_number  filing_id transaction_id  \
# 0                 C00696419    1326529         561500
# 1                 C00696419    1326529         564400
# 2                 C00696419    1326529         564500
# 3                 C00696419    1326529         565000
# 4                 C00696419    1326529         566000
#
#           contribution_date  contribution_amount  contribution_aggregate  \
# 0 2019-02-20 00:00:00-05:00               2800.0                  5600.0
# 1 2019-02-19 00:00:00-05:00               2800.0                  2800.0
# 2 2019-02-18 00:00:00-05:00                250.0                   250.0
# 3 2019-02-19 00:00:00-05:00                100.0                   250.0
# 4 2019-02-19 00:00:00-05:00                 25.0                   325.0
#
#                 donor_id contributor_first_name contributor_last_name  \
# 0  JUSTINE|HASELOW|55436                Justine               Haselow
# 1   MARTIN|CARLSON|55401                 Martin               Carlson
# 2     WILLIAM|BELL|90068                William                  Bell
# 3  REBECCA|BEATTIE|80007                Rebecca               Beattie
# 4   CAROLINE|TOWER|94115               Caroline                 Tower
#
#   contributor_zip_code committee_id Candidate Name
# 0            554361001    C00696419  Amy Klobuchar
# 1            554012159    C00696419  Amy Klobuchar
# 2            900682646    C00696419  Amy Klobuchar
# 3            800076971    C00696419  Amy Klobuchar
# 4            941152418    C00696419  Amy Klobuchar

# %% [markdown]
# ## Aggregate contributions to donor-campaign level
#
# The raw FEC data includes one row for each contribution, so contributors can show up multiple times for a given campaign. Here, we aggregate the data so that it has just one row per contributor-campaign combination:

# %%
# There appear to be some donors who've been refunded to $200 or less
(
    all_indiv_contribs
    .loc[lambda df: df["contribution_aggregate"] <= 200]
    ["donor_id"]
    .nunique()
)
# Out:
# 519

# %%
contributor_totals = (
    all_indiv_contribs
    # Line below removes donors who appear to have been refunded
    # to $200 aggregate or less
    .loc[lambda df: df["contribution_aggregate"] > 200]
    .groupby([
        "donor_id",
        "Candidate Name"
    ])
    ["contribution_amount"]
    .sum()
    .reset_index()
)

contributor_totals.head()
# Out:
#                      donor_id      Candidate Name  contribution_amount
# 0         0-DEREK|EILER|30306      Pete Buttigieg                250.0
# 1  A - DANA SMITH|SMITH|80534      Bernie Sanders                250.0
# 2           A ALEX|LARI|10128  Kirsten Gillibrand               2700.0
# 3           A C|HUDGINS|10025         Cory Booker                250.0
# 4            A J|AGUILA|07631         Andrew Yang                250.0

# %% [markdown]
# ## Distinct donor counts, by candidate

# %%
distinct_donor_counts = (
    contributor_totals
    ["Candidate Name"]
    .value_counts()
    .to_frame("Distinct Donor IDs")
)

distinct_donor_counts
# Out:
#                     Distinct Donor IDs
# Bernie Sanders                    9321
# Kamala Harris                     7489
# Beto O'Rourke                     4879
# Pete Buttigieg                    4045
# Elizabeth Warren                  3177
# Cory Booker                       3063
# Amy Klobuchar                     2867
# Kirsten Gillibrand                1723
# Jay Inslee                        1214
# John Hickenlooper                 1090
# Tulsi Gabbard                      801
# Andrew Yang                        659
# Julián Castro                      576
# John Delaney                       372
# Wayne Messam                        33

# %% [markdown]
# ## Find donors who gave to any two candidates, and any three candidates

# %%
# Added by Steve, what did the dataset look like before the self join?

contributor_totals[['donor_id', 'Candidate Name']].head()
# Out:
#                      donor_id      Candidate Name
# 0         0-DEREK|EILER|30306      Pete Buttigieg
# 1  A - DANA SMITH|SMITH|80534      Bernie Sanders
# 2           A ALEX|LARI|10128  Kirsten Gillibrand
# 3           A C|HUDGINS|10025         Cory Booker
# 4            A J|AGUILA|07631         Andrew Yang

# %%
# Added by Steve, what did the dataset look like after the self join?
contributor_totals[['donor_id', 'Candidate Name']].pipe(lambda df: (
    df.merge(df, how='left', on='donor_id', suffixes = ['_x', '_y'])
)).loc[lambda df: df["Candidate Name_x"] != df["Candidate Name_y"]]
# Out:
#                       donor_id   Candidate Name_x   Candidate Name_y
# 35          AARON|KATZEL|10013         Jay Inslee      Kamala Harris
# 36          AARON|KATZEL|10013      Kamala Harris         Jay Inslee
# 125        ABRAHAM|REICH|19102      Amy Klobuchar         Jay Inslee
# 45850  WILLIAM|VAN BUREN|98117         Jay Inslee     Bernie Sanders
# 45851  WILLIAM|VAN BUREN|98117         Jay Inslee      Beto O'Rourke
# 45852  WILLIAM|VAN BUREN|98117         Jay Inslee   Elizabeth Warren
# 45922    WINIFRED|DOOLEY|91505      Beto O'Rourke        Cory Booker
# 45923    WINIFRED|DOOLEY|91505        Cory Booker      Beto O'Rourke
# 45964          W|WALLACE|97209      Amy Klobuchar      Kamala Harris
# 45965          W|WALLACE|97209      Kamala Harris      Amy Klobuchar
# 45980         YAEL|BRAUN|90024        Cory Booker      Kamala Harris
# 45981         YAEL|BRAUN|90024      Kamala Harris        Cory Booker
# 45988    YAHONNES|CLEARY|10026        Cory Booker      Kamala Harris
# 45989    YAHONNES|CLEARY|10026      Kamala Harris        Cory Booker
# 46119      ZACHARY|BROWN|60606      Kamala Harris     Pete Buttigieg
# 46120      ZACHARY|BROWN|60606     Pete Buttigieg      Kamala Harris
# 46175       ZACK|PARSONS|60073     Bernie Sanders   Elizabeth Warren
# 46176       ZACK|PARSONS|60073   Elizabeth Warren     Bernie Sanders
# 46220       ZOEY|CHENITZ|11225        Cory Booker   Elizabeth Warren
# 46221       ZOEY|CHENITZ|11225   Elizabeth Warren        Cory Booker
#
# [4930 rows x 3 columns]

# %%
candidate_pairs = (
    contributor_totals
    .rename(columns = {
        "Candidate Name": "candidate"
    })
    [[
        "donor_id",
        "candidate"
    ]]
    .pipe(lambda df: (
        df
        .merge(
            df,
            how = "left",
            on = "donor_id",
            suffixes = [ "_x", "_y" ],
        )
    ))
    # This filter prevents us from double-counting candidate-combinations
    .loc[lambda df: df["candidate_x"] < df["candidate_y"]]
    .sort_values([
        "candidate_x",
        "candidate_y",
        "donor_id"
    ])
)

candidate_pairs.head(10)
# Out:
#                    donor_id    candidate_x     candidate_y
# 8287    COLLIER|PERRY|76567  Amy Klobuchar     Andrew Yang
# 18921      JEAN|YNGVE|46304  Amy Klobuchar  Bernie Sanders
# 23339     KAREN|ALLIN|30305  Amy Klobuchar  Bernie Sanders
# 24146   KATHY|GIBBONS|20008  Amy Klobuchar  Bernie Sanders
# 29269     MARK|MOLLOY|50214  Amy Klobuchar  Bernie Sanders
# 29344  MARK|ROTHACHER|84117  Amy Klobuchar  Bernie Sanders
# 29456  MARK|WIZNITZER|22205  Amy Klobuchar  Bernie Sanders
# 34001   PARKE|CAPSHAW|22902  Amy Klobuchar  Bernie Sanders
# 963      ALICE|JARCHO|10065  Amy Klobuchar   Beto O'Rourke
# 1480      AMY|LOFGREN|85250  Amy Klobuchar   Beto O'Rourke

# %%
candidate_triplets = (
    contributor_totals
    .rename(columns = {
        "Candidate Name": "candidate"
    })
    [[
        "donor_id",
        "candidate"
    ]]
    .pipe(lambda df: (
        df
        .merge(
            df,
            how = "left",
            on = "donor_id",
            suffixes = [ "_x", "_y" ],
        )
        .merge(
            df.rename(columns = { "candidate": "candidate_z" }),
            how = "left",
            on = "donor_id",
        )
    ))
    # This filter prevents us from double-counting candidate-combinations
    .loc[lambda df: df["candidate_x"] < df["candidate_y"]]
    .loc[lambda df: df["candidate_y"] < df["candidate_z"]]
    .sort_values([
        "candidate_x",
        "candidate_y",
        "candidate_z",
        "donor_id"
    ])
)

candidate_triplets.head(10)
# Out:
#                      donor_id    candidate_x     candidate_y  \
# 10547     COLLIER|PERRY|76567  Amy Klobuchar     Andrew Yang
# 43322     PARKE|CAPSHAW|22902  Amy Klobuchar  Bernie Sanders
# 37377       MARK|MOLLOY|50214  Amy Klobuchar  Bernie Sanders
# 43323     PARKE|CAPSHAW|22902  Amy Klobuchar  Bernie Sanders
# 29581       KAREN|ALLIN|30305  Amy Klobuchar  Bernie Sanders
# 31040     KEENAN|KELSEY|94939  Amy Klobuchar   Beto O'Rourke
# 5635          BILL|SIMS|75209  Amy Klobuchar   Beto O'Rourke
# 39698  MICHAEL|AUERBACH|10013  Amy Klobuchar   Beto O'Rourke
# 2275     ANDREW|FREDMAN|33156  Amy Klobuchar   Beto O'Rourke
# 2445     ANDREW|MELLETT|90004  Amy Klobuchar   Beto O'Rourke
#
#               candidate_z
# 10547    Elizabeth Warren
# 43322   John Hickenlooper
# 37377       Kamala Harris
# 43323  Kirsten Gillibrand
# 29581      Pete Buttigieg
# 31040         Cory Booker
# 5635     Elizabeth Warren
# 39698    Elizabeth Warren
# 2275    John Hickenlooper
# 2445    John Hickenlooper

# %% [markdown]
# ## Identify the most common two-candidate combinations
#
# Here, we count how many times donors has given to both Candidate X and Candidate Y, irrespective of any other contributions they might have made:

# %%
# Added by Steve

candidate_pairs.groupby(['candidate_x', 'candidate_y']).count()
# Out:
#                                        donor_id
# candidate_x        candidate_y
# Amy Klobuchar      Andrew Yang                1
#                    Bernie Sanders             7
#                    Beto O'Rourke             65
#                    Cory Booker               43
#                    Elizabeth Warren          52
#                    Jay Inslee                24
#                    John Delaney               5
#                    John Hickenlooper         16
#                    Julián Castro              7
#                    Kamala Harris            141
#                    Kirsten Gillibrand        72
#                    Pete Buttigieg           112
# Andrew Yang        Bernie Sanders             8
#                    Beto O'Rourke              3
#                    Elizabeth Warren           4
#                    John Delaney               1
#                    John Hickenlooper          2
#                    Kamala Harris              2
#                    Pete Buttigieg             4
#                    Tulsi Gabbard              2
# Bernie Sanders     Beto O'Rourke             22
#                    Cory Booker                9
#                    Elizabeth Warren         138
#                    Jay Inslee                13
#                    John Hickenlooper          4
#                    Julián Castro              2
#                    Kamala Harris             38
#                    Kirsten Gillibrand         4
#                    Pete Buttigieg            31
#                    Tulsi Gabbard             65
# ...                                         ...
# Elizabeth Warren   Kamala Harris            121
#                    Kirsten Gillibrand        32
#                    Pete Buttigieg            75
#                    Tulsi Gabbard              6
#                    Wayne Messam               1
# Jay Inslee         John Delaney               1
#                    John Hickenlooper          7
#                    Julián Castro              3
#                    Kamala Harris             22
#                    Kirsten Gillibrand         8
#                    Pete Buttigieg            42
# John Delaney       John Hickenlooper          1
#                    Kamala Harris              4
#                    Kirsten Gillibrand         1
#                    Pete Buttigieg             4
# John Hickenlooper  Julián Castro              2
#                    Kamala Harris             15
#                    Kirsten Gillibrand        11
#                    Pete Buttigieg            15
# Julián Castro      Kamala Harris             20
#                    Kirsten Gillibrand         5
#                    Pete Buttigieg            11
#                    Tulsi Gabbard              2
# Kamala Harris      Kirsten Gillibrand       130
#                    Pete Buttigieg           170
#                    Tulsi Gabbard              6
#                    Wayne Messam               1
# Kirsten Gillibrand Pete Buttigieg            26
#                    Tulsi Gabbard              2
# Pete Buttigieg     Tulsi Gabbard              3
#
# [82 rows x 1 columns]

# %%
pair_counts = (
    candidate_pairs
    .groupby([
        "candidate_x",
        "candidate_y",
    ])
    .size()
    .to_frame("count")
    .sort_values("count", ascending = False)
    .reset_index()
)

pair_counts.to_csv(
    "../outputs/candidate-pair-counts.csv",
    index = False
)

pair_counts.loc[lambda df: df["count"] >= 50]
# Out:
#          candidate_x         candidate_y  count
# 0      Kamala Harris      Pete Buttigieg    170
# 1        Cory Booker       Kamala Harris    166
# 2      Beto O'Rourke      Pete Buttigieg    144
# 3      Amy Klobuchar       Kamala Harris    141
# 4     Bernie Sanders    Elizabeth Warren    138
# 5      Kamala Harris  Kirsten Gillibrand    130
# 6      Beto O'Rourke       Kamala Harris    128
# 7   Elizabeth Warren       Kamala Harris    121
# 8      Amy Klobuchar      Pete Buttigieg    112
# 9        Cory Booker  Kirsten Gillibrand     80
# 10  Elizabeth Warren      Pete Buttigieg     75
# 11     Amy Klobuchar  Kirsten Gillibrand     72
# 12    Bernie Sanders       Tulsi Gabbard     65
# 13     Amy Klobuchar       Beto O'Rourke     65
# 14     Amy Klobuchar    Elizabeth Warren     52

# %% [markdown]
# ## Identify the most common three-candidate combinations

# %%
triplet_counts = (
    candidate_triplets
    .groupby([
        "candidate_x",
        "candidate_y",
        "candidate_z",
    ])
    .size()
    .to_frame("count")
    .sort_values("count", ascending = False)
    .reset_index()
)

triplet_counts.to_csv(
    "../outputs/candidate-triplet-counts.csv",
    index = False
)

triplet_counts.loc[lambda df: df["count"] >= 10]
# Out:
#          candidate_x       candidate_y         candidate_z  count
# 0        Cory Booker     Kamala Harris  Kirsten Gillibrand     33
# 1      Amy Klobuchar     Kamala Harris  Kirsten Gillibrand     27
# 2      Beto O'Rourke     Kamala Harris      Pete Buttigieg     26
# 3      Amy Klobuchar     Kamala Harris      Pete Buttigieg     22
# 4      Amy Klobuchar     Beto O'Rourke      Pete Buttigieg     19
# 5   Elizabeth Warren     Kamala Harris      Pete Buttigieg     17
# 6      Amy Klobuchar  Elizabeth Warren       Kamala Harris     17
# 7      Amy Klobuchar       Cory Booker       Kamala Harris     17
# 8   Elizabeth Warren     Kamala Harris  Kirsten Gillibrand     16
# 9        Cory Booker     Kamala Harris      Pete Buttigieg     14
# 10     Amy Klobuchar     Beto O'Rourke       Kamala Harris     10
# 11       Cory Booker  Elizabeth Warren       Kamala Harris     10
# 12     Amy Klobuchar  Elizabeth Warren  Kirsten Gillibrand     10
# 13     Amy Klobuchar       Cory Booker  Kirsten Gillibrand     10
# 14     Amy Klobuchar        Jay Inslee      Pete Buttigieg     10

# %% [markdown]
# ## Count number of donors who gave to at least three female candidates

# %%
(
    contributor_totals
    .loc[lambda df: df["Candidate Name"].isin(
        candidates
        .loc[lambda df: df["Candidate Sex"] == "F"]
        ["Candidate Name"]
    )]
    .groupby([ "donor_id" ])
    ["Candidate Name"]
    .nunique()
    .loc[lambda x: x >= 3]
    .pipe(len)
)
# Out:
# 44

# %% [markdown]
# ## Calculate number of donors, per candidate, that gave to multiple campaigns

# %%
# Added by Steve
candidate_pairs.head()
# Out:
#                   donor_id    candidate_x     candidate_y
# 8287   COLLIER|PERRY|76567  Amy Klobuchar     Andrew Yang
# 18921     JEAN|YNGVE|46304  Amy Klobuchar  Bernie Sanders
# 23339    KAREN|ALLIN|30305  Amy Klobuchar  Bernie Sanders
# 24146  KATHY|GIBBONS|20008  Amy Klobuchar  Bernie Sanders
# 29269    MARK|MOLLOY|50214  Amy Klobuchar  Bernie Sanders

# %%
# Added by Steve
candidate_pairs.melt(id_vars = ["donor_id"], value_name = "candidate").
# Out:
#                           donor_id     variable       candidate
# 0              COLLIER|PERRY|76567  candidate_x   Amy Klobuchar
# 1                 JEAN|YNGVE|46304  candidate_x   Amy Klobuchar
# 2                KAREN|ALLIN|30305  candidate_x   Amy Klobuchar
# 3              KATHY|GIBBONS|20008  candidate_x   Amy Klobuchar
# 4                MARK|MOLLOY|50214  candidate_x   Amy Klobuchar
# 5             MARK|ROTHACHER|84117  candidate_x   Amy Klobuchar
# 6             MARK|WIZNITZER|22205  candidate_x   Amy Klobuchar
# 7              PARKE|CAPSHAW|22902  candidate_x   Amy Klobuchar
# 8               ALICE|JARCHO|10065  candidate_x   Amy Klobuchar
# 9                AMY|LOFGREN|85250  candidate_x   Amy Klobuchar
# 10            ANDREW|FREDMAN|33156  candidate_x   Amy Klobuchar
# 11            ANDREW|LEGRAND|75104  candidate_x   Amy Klobuchar
# 12            ANDREW|MELLETT|90004  candidate_x   Amy Klobuchar
# 13            BARBARA|CLARKE|20016  candidate_x   Amy Klobuchar
# 14           BENJAMIN|GORDON|80230  candidate_x   Amy Klobuchar
# 15                 BILL|SIMS|75209  candidate_x   Amy Klobuchar
# 16            BRIAN|EMANUELS|98040  candidate_x   Amy Klobuchar
# 17             BRONSON|DAVIS|76116  candidate_x   Amy Klobuchar
# 18         CARTER|MCCLELLAND|10023  candidate_x   Amy Klobuchar
# 19          CECILIA|REYNOLDS|85027  candidate_x   Amy Klobuchar
# 20             CHERYL|GEORGE|78746  candidate_x   Amy Klobuchar
# 21             CLIFFORD|MUMM|22740  candidate_x   Amy Klobuchar
# 22           CLIFF|BURNSTEIN|10010  candidate_x   Amy Klobuchar
# 23            COURTNEY|KEITH|56031  candidate_x   Amy Klobuchar
# 24            DANIEL|TIERNEY|60611  candidate_x   Amy Klobuchar
# 25               DAVID|ROSEN|79705  candidate_x   Amy Klobuchar
# 26              ELAINE|GOLIN|11231  candidate_x   Amy Klobuchar
# 27           ELIAS|KEFALIDIS|10010  candidate_x   Amy Klobuchar
# 28               ERIC|ROSAND|20007  candidate_x   Amy Klobuchar
# 29            FRED|HUEBSCHER|90254  candidate_x   Amy Klobuchar
# ...                            ...          ...             ...
# 4900      BARBARA|GRASSESCHI|95448  candidate_y  Pete Buttigieg
# 4901        CLAIRE|SILBERMAN|11201  candidate_y  Pete Buttigieg
# 4902         DEE DEE|CHESLEY|60614  candidate_y  Pete Buttigieg
# 4903       ELIZABETH|NAFTALI|91604  candidate_y  Pete Buttigieg
# 4904           ELLYN|LINDSAY|90034  candidate_y  Pete Buttigieg
# 4905            FAISAL|HALUM|75205  candidate_y  Pete Buttigieg
# 4906         GABRIELA|HEARST|10014  candidate_y  Pete Buttigieg
# 4907           IRENE|BANNING|12567  candidate_y  Pete Buttigieg
# 4908           JONATHAN|DANA|20010  candidate_y  Pete Buttigieg
# 4909          KATHLEEN|MARSH|90046  candidate_y  Pete Buttigieg
# 4910               KEITH|FOX|06897  candidate_y  Pete Buttigieg
# 4911               LISA|NASH|94402  candidate_y  Pete Buttigieg
# 4912           MEREDITH|KANE|10013  candidate_y  Pete Buttigieg
# 4913         MICHAEL|SENNOTT|11201  candidate_y  Pete Buttigieg
# 4914            PAUL|BOSKIND|10036  candidate_y  Pete Buttigieg
# 4915             PENNY|SHANE|10004  candidate_y  Pete Buttigieg
# 4916            ROBERT|BRADY|06878  candidate_y  Pete Buttigieg
# 4917             ROBERT|WOLF|10577  candidate_y  Pete Buttigieg
# 4918           SEAN|ELDRIDGE|10011  candidate_y  Pete Buttigieg
# 4919              SETH|ROSEN|10025  candidate_y  Pete Buttigieg
# 4920            SHERYL|KLEIN|94301  candidate_y  Pete Buttigieg
# 4921          THEODORE|WELLS|07039  candidate_y  Pete Buttigieg
# 4922             TRAVIS|WORL|60660  candidate_y  Pete Buttigieg
# 4923          TRICIA|HERRICK|94306  candidate_y  Pete Buttigieg
# 4924           WENDY|SERRINO|60022  candidate_y  Pete Buttigieg
# 4925  CHRISTOPHER|MELEDANDRI|90025  candidate_y   Tulsi Gabbard
# 4926           MICHAEL|FRIED|59101  candidate_y   Tulsi Gabbard
# 4927            BRIAN|WILSON|91403  candidate_y   Tulsi Gabbard
# 4928             KATE|DUBRAY|22042  candidate_y   Tulsi Gabbard
# 4929               LES|VOGEL|94607  candidate_y   Tulsi Gabbard
#
# [4930 rows x 3 columns]

# %%
# Added by Steve, what does melt do?

print(candidate_pairs.head())
candidate_pairs.melt(id_vars = ["donor_id"], value_name = "candidate").head()
# Out:
#                   donor_id    candidate_x     candidate_y
# 8287   COLLIER|PERRY|76567  Amy Klobuchar     Andrew Yang
# 18921     JEAN|YNGVE|46304  Amy Klobuchar  Bernie Sanders
# 23339    KAREN|ALLIN|30305  Amy Klobuchar  Bernie Sanders
# 24146  KATHY|GIBBONS|20008  Amy Klobuchar  Bernie Sanders
# 29269    MARK|MOLLOY|50214  Amy Klobuchar  Bernie Sanders
#               donor_id     variable      candidate
# 0  COLLIER|PERRY|76567  candidate_x  Amy Klobuchar
# 1     JEAN|YNGVE|46304  candidate_x  Amy Klobuchar
# 2    KAREN|ALLIN|30305  candidate_x  Amy Klobuchar
# 3  KATHY|GIBBONS|20008  candidate_x  Amy Klobuchar
# 4    MARK|MOLLOY|50214  candidate_x  Amy Klobuchar

# %%
# Added by Steve, what's going on?
# Distinct Donor IDs are the number of donors who donated to the candidate
(
    candidate_pairs
        .melt(
            id_vars = [ "donor_id" ],
            value_name = "candidate"
        )
        .groupby([ "candidate" ])
        ["donor_id"]
        .nunique()
        .sort_values(ascending = False)
        .to_frame("Multiple-Candidate Donors")
        .join(
            distinct_donor_counts,
            how = "left"
        )
)
# Out:
#                     Multiple-Candidate Donors  Distinct Donor IDs
# candidate
# Kamala Harris                             722                7489
# Pete Buttigieg                            512                4045
# Elizabeth Warren                          420                3177
# Beto O'Rourke                             394                4879
# Amy Klobuchar                             386                2867
# Cory Booker                               313                3063
# Bernie Sanders                            296                9321
# Kirsten Gillibrand                        277                1723
# Jay Inslee                                128                1214
# Tulsi Gabbard                              79                 801
# John Hickenlooper                          68                1090
# Julián Castro                              52                 576
# Andrew Yang                                22                 659
# John Delaney                               18                 372
# Wayne Messam                                2                  33

# %%
(
    candidate_pairs
    .melt(
        id_vars = [ "donor_id" ],
        value_name = "candidate"
    )
    .groupby([ "candidate" ])
    ["donor_id"]
    .nunique()
    .sort_values(ascending = False)
    .to_frame("Multiple-Candidate Donors")
    .join(
        distinct_donor_counts,
        how = "left"
    )
    .assign(**{
        "Per 1k": lambda df: (
            df["Multiple-Candidate Donors"] * 1000 /
            df["Distinct Donor IDs"]
        ).round(1)
    })
)
# Out:
#                     Multiple-Candidate Donors  Distinct Donor IDs  Per 1k
# candidate
# Kamala Harris                             722                7489    96.4
# Pete Buttigieg                            512                4045   126.6
# Elizabeth Warren                          420                3177   132.2
# Beto O'Rourke                             394                4879    80.8
# Amy Klobuchar                             386                2867   134.6
# Cory Booker                               313                3063   102.2
# Bernie Sanders                            296                9321    31.8
# Kirsten Gillibrand                        277                1723   160.8
# Jay Inslee                                128                1214   105.4
# Tulsi Gabbard                              79                 801    98.6
# John Hickenlooper                          68                1090    62.4
# Julián Castro                              52                 576    90.3
# Andrew Yang                                22                 659    33.4
# John Delaney                               18                 372    48.4
# Wayne Messam                                2                  33    60.6

# %% [markdown]
# ## Calculate total number of donors observed giving to multiple campaigns

# %%
donor_candidate_counts = (
    contributor_totals
    .groupby(["donor_id"])
    .size()
    .to_frame("num_candidates")
    .reset_index()
)

(
    donor_candidate_counts
    ["num_candidates"]
    .value_counts()
    .sort_index()
)
# Out:
# 1    37620
# 2     1401
# 3      203
# 4       55
# 5        8
# 6        3
# Name: num_candidates, dtype: int64

# %% [markdown]
# ... and as a proportion of the total:

# %%
(
    donor_candidate_counts
    ["num_candidates"]
    .value_counts(normalize = True)
    .sort_index()
)
# Out:
# 1    0.957496
# 2    0.035658
# 3    0.005167
# 4    0.001400
# 5    0.000204
# 6    0.000076
# Name: num_candidates, dtype: float64

# %% [markdown]
# ---
#
# ---
#
# ---
